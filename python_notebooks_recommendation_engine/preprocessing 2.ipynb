# %%
#importing the required libraries, pd and np: abbreviations for the imported libraries
import numpy as np
import pandas as pd

# %%
#reading credits csv file
credits = pd.read_csv('C:/Users/rush2/Documents/Movieflix/datasets/credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
#reading metadata file
movie_metadata = pd.read_csv('C:/Users/rush2/Documents/Movieflix/datasets/movies_metadata.csv')
# Out:
# C:\Users\rush2\AppData\Local\Temp/ipykernel_4428/4167918389.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_metadata = pd.read_csv('C:/Users/rush2/Documents/Movieflix/datasets/movies_metadata.csv')

# %%
movie_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie_metadata.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#converting release-date column to datetime
movie_metadata['release_date'] = pd.to_datetime(movie_metadata['release_date'], errors='coerce')

# %%
movie_metadata['year'] = movie_metadata['release_date'].dt.year

# %%
movie_metadata['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
movie_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Getting only 2017 movies as we already have movies up to the year 2016 in preprocessing 1 file. 
# We don't have enough data for the movies from 2018, 2019 and 2020. 
# We'll deal with it in the upcoming preprocessing files
new_meta = movie_metadata.loc[movie_metadata.year <= 2017,['genres','id','title','year']]

# %%
new_meta.head()
# Out:
#                                               genres     id  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#                          title    year
# 0                    Toy Story  1995.0
# 1                      Jumanji  1995.0
# 2             Grumpier Old Men  1995.0
# 3            Waiting to Exhale  1995.0
# 4  Father of the Bride Part II  1995.0

# %%
#casting new_meta panda object to a specified datatype
new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta, credits, on='id')

# %%
pd.set_option('display.max_colwidth', 75)
data
# Out:
#                                                                            genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': ...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id':...
# 2                [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 1074...
# 4                                                  [{'id': 35, 'name': 'Comedy'}]
# ...                                                                           ...
# 45440  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 1074...
# 45441                                               [{'id': 18, 'name': 'Drama'}]
# 45442  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, ...
# 45443                                                                          []
# ...

# %%
# evaluates an expression node or a conatiner display or a string containing a Python literal 
import ast
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))

# %%
#function to generate a list based on genre
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0         Animation Comedy Family
# 1        Adventure Fantasy Family
# 2                  Romance Comedy
# 3            Comedy Drama Romance
# 4                          Comedy
#                    ...
# 45440        Drama Action Romance
# 45441                       Drama
# 45442       Action Drama Thriller
# 45443                         NaN
# 45444                         NaN
# Name: genres_list, Length: 45445, dtype: object

# %%
#function to get the first actor's information
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
#function to get the second actor's information
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0                Tim Allen
# 1            Jonathan Hyde
# 2              Jack Lemmon
# 3           Angela Bassett
# 4             Diane Keaton
#                ...
# 45440          Uma Thurman
# 45441          Perry Dizon
# 45442         Adam Baldwin
# 45443    Nathalie Lissenko
# 45444                  NaN
# Name: actor_2_name, Length: 45445, dtype: object

# %%
#function to get the third actor's information
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0            Don Rickles
# 1          Kirsten Dunst
# 2            Ann-Margret
# 3         Loretta Devine
# 4           Martin Short
#               ...
# 45440    David Morrissey
# 45441      Hazel Orencio
# 45442      Julie du Page
# 45443       Pavel Pavlov
# 45444                NaN
# Name: actor_3_name, Length: 45445, dtype: object

# %%
#function to get the director's information from a list of several professions such as producers, casting-directors
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 45440          John Irvin
# 45441            Lav Diaz
# 45442      Mark L. Lester
# 45443    Yakov Protazanov
# 45444       Daisy Asquith
# Name: director_name, Length: 45445, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#           director_name      actor_1_name       actor_2_name     actor_3_name  \
# 0         John Lasseter         Tom Hanks          Tim Allen      Don Rickles
# 1          Joe Johnston    Robin Williams      Jonathan Hyde    Kirsten Dunst
# 2         Howard Deutch    Walter Matthau        Jack Lemmon      Ann-Margret
# 3       Forest Whitaker   Whitney Houston     Angela Bassett   Loretta Devine
# 4         Charles Shyer      Steve Martin       Diane Keaton     Martin Short
# ...                 ...               ...                ...              ...
# 45440        John Irvin    Patrick Bergin        Uma Thurman  David Morrissey
# 45441          Lav Diaz      Angel Aquino        Perry Dizon    Hazel Orencio
# 45442    Mark L. Lester     Erika Eleniak       Adam Baldwin    Julie du Page
# 45443  Yakov Protazanov  Iwan Mosschuchin  Nathalie Lissenko     Pavel Pavlov
# 45444     Daisy Asquith               NaN                NaN              NaN
#
# ...

# %%
#checking the sum of null values in every column
movie.isna().sum()
# Out:
# director_name     835
# actor_1_name     2354
# actor_2_name     3683
# actor_3_name     4593
# genres_list      2384
# title               0
# dtype: int64

# %%
#dropping the rows which has null values
movie = movie.dropna(how='any')

# %%
#checking the sum of null values to verify if it still has null values
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
#renaming the columns' names for simplicity
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
#combining all the features and adding them under one tag
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 45438         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 45439    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 45440       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 45441         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 45442   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# ...

# %%
old = pd.read_csv('data.csv')

# %%
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

# %%
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
new = old.append(movie)
# Out:
# C:\Users\rush2\AppData\Local\Temp/ipykernel_4428/3034453481.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = old.append(movie)

# %%
new
# Out:
#            director_name     actor_1_name      actor_2_name  \
# 0          James Cameron      CCH Pounder  Joel David Moore
# 1         Gore Verbinski      Johnny Depp     Orlando Bloom
# 2             Sam Mendes  Christoph Waltz      Rory Kinnear
# 3      Christopher Nolan        Tom Hardy    Christian Bale
# 4            Doug Walker      Doug Walker        Rob Walker
# ...                  ...              ...               ...
# 45438           Ben Rock       Monty Bane       Lucy Butler
# 45439      Aaron Osborne       Lisa Boyle         Kena Land
# 45440         John Irvin   Patrick Bergin       Uma Thurman
# 45441           Lav Diaz     Angel Aquino       Perry Dizon
# 45442     Mark L. Lester    Erika Eleniak      Adam Baldwin
#
#                actor_3_name                           genres  \
# 0                 Wes Studi  Action Adventure Fantasy Sci-Fi
# 1            Jack Davenport         Action Adventure Fantasy
# ...

# %%
#dropping duplicates
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new
# Out:
#            director_name     actor_1_name      actor_2_name  \
# 0          James Cameron      CCH Pounder  Joel David Moore
# 1         Gore Verbinski      Johnny Depp     Orlando Bloom
# 2             Sam Mendes  Christoph Waltz      Rory Kinnear
# 3      Christopher Nolan        Tom Hardy    Christian Bale
# 4            Doug Walker      Doug Walker        Rob Walker
# ...                  ...              ...               ...
# 45438           Ben Rock       Monty Bane       Lucy Butler
# 45439      Aaron Osborne       Lisa Boyle         Kena Land
# 45440         John Irvin   Patrick Bergin       Uma Thurman
# 45441           Lav Diaz     Angel Aquino       Perry Dizon
# 45442     Mark L. Lester    Erika Eleniak      Adam Baldwin
#
#                actor_3_name                           genres  \
# 0                 Wes Studi  Action Adventure Fantasy Sci-Fi
# 1            Jack Davenport         Action Adventure Fantasy
# ...

# %%
new.to_csv('new_dataset.csv',index=False)
